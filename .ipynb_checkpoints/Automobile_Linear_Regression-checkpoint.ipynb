# %%
import pandas as pd
import numpy as np

# %%
auto_price = pd.read_csv(r'C:\Users\steph\bepec\Machine Learning\Stream Lit\automobile_pricingLlinearRegression\data\Automobile price data _Raw_.csv', na_values="?")

# %%
auto_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
auto_price.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
obj_auto_price = auto_price.select_dtypes(include="object").copy()

# %%
obj_auto_price.head(5)
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine-location engine-type num-of-cylinders fuel-system
# 0           front        dohc             four        mpfi
# 1           front        dohc             four        mpfi
# 2           front        ohcv              six        mpfi
# 3           front         ohc             four        mpfi
# 4           front         ohc             five        mpfi

# %%
obj_auto_price[obj_auto_price.isnull().any(axis=1)]
# Out:
#      make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 27  dodge       gas      turbo          NaN      sedan          fwd
# 63  mazda    diesel        std          NaN      sedan          fwd
#
#    engine-location engine-type num-of-cylinders fuel-system
# 27           front         ohc             four        mpfi
# 63           front         ohc             four         idi

# %%
obj_auto_price['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
obj_auto_price = obj_auto_price.fillna({"num-of-doors":"four"})

# %%
obj_auto_price['num-of-cylinders'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64

# %%
cleanup_nums = {"num-of-doors":{"four":4, "two":2},
               "num-of-cylinders":{"four":4,"six":6,"five":5,"eight":8,"two":2,"three":3,"twelve":12}}

# %%
obj_auto_price = obj_auto_price.replace(cleanup_nums)

# %%
obj_auto_price.head(5)
# Out:
#           make fuel-type aspiration  num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std             2  convertible          rwd
# 1  alfa-romero       gas        std             2  convertible          rwd
# 2  alfa-romero       gas        std             2    hatchback          rwd
# 3         audi       gas        std             4        sedan          fwd
# 4         audi       gas        std             4        sedan          4wd
#
#   engine-location engine-type  num-of-cylinders fuel-system
# 0           front        dohc                 4        mpfi
# 1           front        dohc                 4        mpfi
# 2           front        ohcv                 6        mpfi
# 3           front         ohc                 4        mpfi
# 4           front         ohc                 5        mpfi

# %%
obj_auto_price.dtypes
# Out:
# make                object
# fuel-type           object
# aspiration          object
# num-of-doors         int64
# body-style          object
# drive-wheels        object
# engine-location     object
# engine-type         object
# num-of-cylinders     int64
# fuel-system         object
# dtype: object

# %%
obj_auto_price["body-style"]  = obj_auto_price["body-style"].astype('category')

# %%
obj_auto_price["body-style"].dtype
# Out:
# CategoricalDtype(categories=['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'], ordered=False)

# %%
obj_auto_price["body-style-cat"] = obj_auto_price["body-style"].cat.codes

# %%
obj_auto_price.head(10)
# Out:
#           make fuel-type aspiration  num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std             2  convertible          rwd
# 1  alfa-romero       gas        std             2  convertible          rwd
# 2  alfa-romero       gas        std             2    hatchback          rwd
# 3         audi       gas        std             4        sedan          fwd
# 4         audi       gas        std             4        sedan          4wd
# 5         audi       gas        std             2        sedan          fwd
# 6         audi       gas        std             4        sedan          fwd
# 7         audi       gas        std             4        wagon          fwd
# 8         audi       gas      turbo             4        sedan          fwd
# 9         audi       gas      turbo             2    hatchback          4wd
#
#   engine-location engine-type  num-of-cylinders fuel-system  body-style-cat
# ...

# %%
pd.get_dummies(obj_auto_price, columns=["drive-wheels"]).head(10)
# Out:
#           make fuel-type aspiration  num-of-doors   body-style  \
# 0  alfa-romero       gas        std             2  convertible
# 1  alfa-romero       gas        std             2  convertible
# 2  alfa-romero       gas        std             2    hatchback
# 3         audi       gas        std             4        sedan
# 4         audi       gas        std             4        sedan
# 5         audi       gas        std             2        sedan
# 6         audi       gas        std             4        sedan
# 7         audi       gas        std             4        wagon
# 8         audi       gas      turbo             4        sedan
# 9         audi       gas      turbo             2    hatchback
#
#   engine-location engine-type  num-of-cylinders fuel-system  body-style-cat  \
# 0           front        dohc                 4        mpfi               0
# 1           front        dohc                 4        mpfi               0
# ...

# %%
pd.get_dummies(obj_auto_price, columns=["body-style","drive-wheels"], prefix=["body","drive"]).head(10)
# Out:
#           make fuel-type aspiration  num-of-doors engine-location engine-type  \
# 0  alfa-romero       gas        std             2           front        dohc
# 1  alfa-romero       gas        std             2           front        dohc
# 2  alfa-romero       gas        std             2           front        ohcv
# 3         audi       gas        std             4           front         ohc
# 4         audi       gas        std             4           front         ohc
# 5         audi       gas        std             2           front         ohc
# 6         audi       gas        std             4           front         ohc
# 7         audi       gas        std             4           front         ohc
# 8         audi       gas      turbo             4           front         ohc
# 9         audi       gas      turbo             2           front         ohc
#
#    num-of-cylinders fuel-system  body-style-cat  OHC_code  body_convertible  \
# ...

# %%
obj_auto_price["engine-type"].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: engine-type, dtype: int64

# %%
obj_auto_price["engine-type"].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: engine-type, dtype: int64

# %%
obj_auto_price["OHC_code"] = np.where(obj_auto_price["engine-type"].str.contains("ohc"),1,0)

# %%
obj_auto_price[['make', 'engine-type', 'OHC_code']].head(5)
# Out:
#           make engine-type  OHC_code
# 0  alfa-romero        dohc         1
# 1  alfa-romero        dohc         1
# 2  alfa-romero        ohcv         1
# 3         audi         ohc         1
# 4         audi         ohc         1

# %%
obj_auto_price.head(5)
# Out:
#           make fuel-type aspiration  num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std             2  convertible          rwd
# 1  alfa-romero       gas        std             2  convertible          rwd
# 2  alfa-romero       gas        std             2    hatchback          rwd
# 3         audi       gas        std             4        sedan          fwd
# 4         audi       gas        std             4        sedan          4wd
#
#   engine-location engine-type  num-of-cylinders fuel-system  body-style-cat  \
# 0           front        dohc                 4        mpfi               0
# 1           front        dohc                 4        mpfi               0
# 2           front        ohcv                 6        mpfi               2
# 3           front         ohc                 4        mpfi               3
# 4           front         ohc                 5        mpfi               3
#
#    OHC_code
# 0         1
# 1         1
# ...
